# %%
#Import packages
import requests
import io
import ast
import math
import urllib.request
import flipp_data_extracter
from PIL import Image
from io import BytesIO
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Information needed for data extraction
item_name = 'chicken'
zip_code = 60565

# %%
#results list of dictionarys of query items
Output = flipp_data_extracter.search(item_name, zip_code)

# %%
display(len(Output))
# Out:
# 150

# %%
# view dictionary 
Output[0]['item'].items()
# Out:
# dict_items([('id', 537536105), ('flyer_id', 3850927), ('flyer_valid_from', '2020-12-30T00:00:00-05:00'), ('flyer_valid_to', '2021-01-26T23:59:59-05:00'), ('brand', None), ('display_type', 1), ('merchant', 'Walmart'), ('merchant_id', 2175), ('merchant_logo', 'http://images.wishabi.net/merchants/2175/1399558010/medium'), ('name', 'Fresh Chicken Drumsticks'), ('image_url', 'http://f.wishabi.net/page_pdf_images/11100025/13bbfba0-3bf3-11eb-80e3-0e7faade0358/x_large'), ('cutout_image_url', 'http://f.wishabi.net/page_items/209112558/1609802912/extra_large.jpg'), ('media', []), ('description', None), ('current_price', ''), ('current_price_range', None), ('pre_price_text', None), ('category', ''), ('price_text', None), ('sale_story', 'Everyday Low Price'), ('original_price', None), ('original_price_range', None), ('in_store_only', True), ('disclaimer_text', 'Brands may vary by store.'), ('flyer_disclaimer_text', ''), ('valid_from', None), ('valid_to', None), ('timezone', -300), ('sku', None), ('ttm_label', 'Find a store'), ('ttm_url', 'https://www.walmart.com/cservice/ca_storefinder.gsp'), ('show_details', True), ('review_average_rating', None), ('review_count', 0), ('review_samples', []), ('reviews_most_recent', []), ('specs', []), ('features', []), ('related_items', []), ('shipping_info', {'tag_line': 'Shipping policy', 'details_url': 'https://help.walmart.com/app/answers/detail/a_id/1544/kw/shipping'}), ('return_info', {'tag_line': 'Return policy', 'details_url': 'https://help.walmart.com/app/answers/detail/a_id/9'}), ('top', -350.562), ('bottom', -705.45), ('left', 3264.23), ('right', 3985.1), ('percent_off', None), ('dollars_off', None)])

# %%
def select_df(list_dics_all):
    '''
    Results a datafram of selected items reading a list of 
    dictionaries of extracted items.
    '''
    #Reading data from Output dictionary
    selected_cols = ['brand', 'merchant', 'name', 'category', 'description', 
                                           'current_price', 'price_text', 'percent_off','image_url','cutout_image_url']
    df_all_items = pd.DataFrame(columns = selected_cols) # dataframe from selected items

    list_dic_selected_items =[]  # list of dictionaries with selected item desriptions only


    for i in range(len(Output)):
        items_dict = Output[i]['item']
        selected_dict = {}

        for key in items_dict:
            if key in selected_cols:
                selected_dict[key] = items_dict[key]                   
        list_dic_selected_items.append(selected_dict)   #update list with dictinaries for each group
    df_all_items = df_all_items.append(list_dic_selected_items, True)   # append list to dataframe 
    return df_all_items

# %%
df_sel = select_df(Output)

# %%
df_sel.head(20)
# Out:
#      brand                      merchant  \
# 0     None                       Walmart
# 1     None                       Walmart
# 2     None                       Walmart
# 3     None                       Walmart
# 4     None            Fresh Thyme Market
# 5     None                       Costco
# 6     None                     Mariano's
# 7     None                          ALDI
# 8     None                          ALDI
# 9     None                    Jewel-Osco
# 10    None  Angelo Caputo's Fresh Market
# 11    None                        Meijer
# 12  Tyson®                Dollar General
# 13    None                    Save A Lot
# 14    None  Angelo Caputo's Fresh Market
# 15    None           Tony's Fresh Market
# 16    None                    Save A Lot
# 17    None                       Walmart
# 18    None                       Walmart
# 19    None                        Meijer
#
#                                                  name category  \
# 0                            Fresh Chicken Drumsticks
# 1                                 Fresh Chicken Wings
# 2                    Boneless Skinless Chicken Thighs
# 3                          Chicken Breast Tenderloins
# 4   100% Antibiotic-Free Fresh Thyme Chicken Drums...
# 5                         Tyson Crispy Chicken Strips
# 6   Rotisserie Chicken, 8-Piece Fried Chicken, or ...
# 7   Bremer Buffalo Style Chicken or Mushroom & Swi...
# 8   Appetitos Buffalo Chicken or Bacon Mac & Chees...
# 9   Sesame Orange Chicken Bowl, Crispy Honey Chick...
# 10   2453 N3 PERDUE e Tano INS oue af AN PERDUE A ...
# 11               Meijer Frozen Chicken Breast Nuggets
# 12  Tyson® All Natural Boneless Skinless Chicken B...
# 13   -11004t CHICKEN 010C OVAN 1.99 Marcum Chicken...
# 14   U.S.D.A. Grade "A" Fresh Poultry Seasoned Chi...
# 15   Srkhis CCTN TRA WASA Srkhis C1CVRN Sukhi's Ch...
# 16   MARKET SELECTIONS MARKET 3.99 SELECTIONS Mark...
# 17                    Antibiotic-Free Chicken Breasts
# 18            Great Value All Natural Chicken Breasts
# 19  Meijer Stuffed Chicken Breasts 30 oz. or Chick...
#
#                                   description current_price  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None          1.69
# 5                                        None
# 6                 from our deli\nMIX OR MATCH          10.0
# 7                            22–26 oz. Frozen          5.49
# 8                                9 oz. Frozen          3.99
# 9     8 oz. - 24 oz.\nSingle Item Price $6.00           5.0
# 10                                       None
# 11                                   70.4 oz.          6.99
# 12                         32 oz. Sold Frozen          5.95
# 13                                       None
# 14                                       None
# 15                                       None
# 16                                       None
# 17  Boneless & Skinless, Individually Wrapped
# 18                 Boneless & Skinless, 5 lbs
# 19                                    Frozen.
#
#                   price_text  percent_off  \
# 0                       None          NaN
# 1                       None          NaN
# 2                       None          NaN
# 3                       None          NaN
# 4                         LB          NaN
# 5                       None          NaN
# 6   When you buy 2 With Card          NaN
# 7                       None          NaN
# 8                       None          NaN
# 9                        ea.          NaN
# 10                      None          NaN
# 11                      None          NaN
# 12                      None          NaN
# 13                      None          NaN
# 14                      None          NaN
# 15                      None          NaN
# 16                      None          NaN
# 17                      None          NaN
# 18                      None          NaN
# 19                      None          NaN
#
#                                             image_url  \
# 0   http://f.wishabi.net/page_pdf_images/11100025/...
# 1   http://f.wishabi.net/page_pdf_images/11100025/...
# 2   http://f.wishabi.net/page_pdf_images/11100025/...
# 3   http://f.wishabi.net/page_pdf_images/11100025/...
# 4   http://f.wishabi.net/page_pdf_images/11238265/...
# 5   http://f.wishabi.net/page_items/210327927/1609...
# 6   http://f.wishabi.net/page_items/211346312/1610...
# 7   http://f.wishabi.net/page_items/210013825/1610...
# 8   http://f.wishabi.net/page_items/210013834/1610...
# 9   http://f.wishabi.net/page_pdf_images/11232490/...
# 10  http://f.wishabi.net/page_items/212482573/1611...
# 11  http://f.wishabi.net/page_items/211293671/1611...
# 12  http://f.wishabi.net/page_items/211663216/1610...
# 13  http://f.wishabi.net/page_items/212372673/1611...
# 14  http://f.wishabi.net/page_items/212482575/1611...
# 15  http://f.wishabi.net/page_items/212349527/1611...
# 16  http://f.wishabi.net/page_items/212393459/1611...
# 17  http://f.wishabi.net/page_pdf_images/11100025/...
# 18  http://f.wishabi.net/page_item_supplemental_in...
# 19  http://f.wishabi.net/page_items/211665777/1611...
#
#                                      cutout_image_url
# 0   http://f.wishabi.net/page_items/209112558/1609...
# 1   http://f.wishabi.net/page_items/209112560/1609...
# 2   http://f.wishabi.net/page_items/209112554/1609...
# 3   http://f.wishabi.net/page_items/209112556/1609...
# 4   http://f.wishabi.net/page_items/211859069/1611...
# 5   http://f.wishabi.net/page_items/210327927/1609...
# 6   http://f.wishabi.net/page_items/211346312/1610...
# 7   http://f.wishabi.net/page_items/210013825/1610...
# 8   http://f.wishabi.net/page_items/210013834/1610...
# 9   http://f.wishabi.net/page_items/211645842/1611...
# 10  http://f.wishabi.net/page_items/212482573/1611...
# 11  http://f.wishabi.net/page_items/211293671/1611...
# 12  http://f.wishabi.net/page_items/211663216/1610...
# 13  http://f.wishabi.net/page_items/212372673/1611...
# 14  http://f.wishabi.net/page_items/212482575/1611...
# 15  http://f.wishabi.net/page_items/212349527/1611...
# 16  http://f.wishabi.net/page_items/212393459/1611...
# 17  http://f.wishabi.net/page_items/209112551/1609...
# 18  http://f.wishabi.net/page_items/209112598/1609...
# 19  http://f.wishabi.net/page_items/211665777/1611...

# %%
len(df_sel['current_price'])
# Out:
# 150

# %%
len(df_sel[df_sel['current_price'] == ''])
# Out:
# 88

# %%
df_sel['ext_price'] = np.nan
df_sel['ext_weight(oz)'] = np.nan

# %%
df_sel.tail()
# Out:
#               brand                      merchant  \
# 145            None  Angelo Caputo's Fresh Market
# 146            None                    Save A Lot
# 147            None                 Trader Joe's
# 148  Signature Cafe                    Jewel-Osco
# 149            None                      GameStop
#
#                                                   name category  \
# 145   JOSE. Jose Ole Taquitos OLE Chicken & Cheese,...
# 146   Less than $2 per serving" Chicken Tortellini ...
# 147           Everything But The Bagel Seasoning Blend
# 148                           Signature Cafe Stromboli
# 149                             Harvest Moon One World
#
#                                            description current_price  \
# 145                                               None
# 146                                               None
# 147  Everything But the Bagel Sesame Seasoning Blen...          1.99
# 148       7 oz., Chicken Pesto or\nThree Meat & Cheese          3.99
# 149                        PLUSH CHICKEN with purchase
#
#     price_text  percent_off  \
# 145       None          NaN
# 146       None          NaN
# 147       None          NaN
# 148        ea.          NaN
# 149       None          NaN
#
#                                              image_url  \
# 145  http://f.wishabi.net/page_items/212482302/1611...
# 146  http://f.wishabi.net/page_items/212372756/1611...
# 147  http://f.wishabi.net/page_pdf_images/11276913/...
# 148  http://f.wishabi.net/page_pdf_images/11232492/...
# 149  http://f.wishabi.net/page_pdf_images/11231762/...
#
#                                       cutout_image_url  ext_price  \
# 145  http://f.wishabi.net/page_items/212482302/1611...        NaN
# 146  http://f.wishabi.net/page_items/212372756/1611...        NaN
# 147  http://f.wishabi.net/page_items/212516356/1611...        NaN
# 148  http://f.wishabi.net/page_items/211645108/1611...        NaN
# 149  http://f.wishabi.net/page_items/211643359/1610...        NaN
#
#      ext_weight(oz)
# 145             NaN
# 146             NaN
# 147             NaN
# 148             NaN
# 149             NaN

# %%
for i in range(len(df_sel)):
        comb_text = str(df_sel['name'][i])+ ',' + str(df_sel['description'][i]) + ','+  str(df_sel['price_text'][i])
       
      #Extract oz and lb
        tw1 = re.findall(r'(\d*\.?\d+)(\s?|\\n|-|.)(?i)(oz|lb|0z|lbs|fl)', comb_text)    
        tw2 = re.findall(r'(\s?)(?i)(oz|lb)', comb_text)
        
        fwegt = tw1 or tw2 
        #print(i, fwegt,  comb_text)
        if fwegt !=[]:
            wt_num = fwegt[0]  # pick the first one for multitple entries
            if len(wt_num)==3:  # there is numerical value, space and unit lb or oz
                wt_num1 = ast.literal_eval(wt_num[0]) # numerical value
                wt_unt1 = wt_num[2] # unit becasue second would be space
                #print(type(wt_num1),wt_num1, wt_unt1)
                if wt_unt1.lower() == 'lb':  # in order to convert lb to oz
                    #print(type(wt_num1),wt_num1, wt_unt1)
                    if type(wt_num1) == int:
                        if wt_num1 > 0 and wt_num1 <= 9:
                            num_lb = float(wt_num1 * 16.0) 
                            df_sel['ext_weight(oz)'][i] = num_lb
                            #print(wt_num1, wt_unt1, num_lb)
                        else:  # if integer is very large
                            df_sel['ext_weight(oz)'][i] = float(16.0)
                            
                    else:               # either emptly or any other large number or decimal
                        str_num = str(wt_num1)
                        cnt_deci =  str_num[::-1].find('.')
                        if cnt_deci == 1:
                            df_sel['ext_weight(oz)'][i] = float(wt_num1) * 16.0
                        else:
                            df_sel['ext_weight(oz)'][i] = float(16)
                elif wt_unt1.lower() =='oz' or wt_unt1.lower() =='0z' or wt_unt1.lower() =='fl': # in case of oz 
                    num_oz = wt_num1
                    df_sel['ext_weight(oz)'][i] = num_oz   
                                   
            else:  #  either there is space or no space and unit
                wt_num2 = wt_num[0] # numerical value or empty
                wt_unt2 = wt_num[1]  #unit lb or oz
                #print(wt_num2,',', wt_unt2, fwegt)
                if wt_unt2.lower == 'oz': #it oz so just 1#
                    df_sel['ext_weight(oz)'][i] = float(1.0)
                else: # it oz so just 1# if it is lb convert ot oz
                    df_sel['ext_weight(oz)'][i] = float(16.0)

# %%
df_wgt = df_sel.dropna(subset = ['ext_weight(oz)'])

# %%
df_sel.shape, df_wgt.shape
# Out:
# ((150, 12), (116, 12))

# %%
df_wgt['price_text'].unique()
# Out:
# array(['LB', None, 'ea.', 'Per Lb.', 'each', 'lb.', 'Each', 'lb'],
#       dtype=object)

# %%
df_wgti = df_wgt.reset_index() # reindex the dataframe after dropping rows with missing units

# %%
df_wgti.head()
# Out:
#    index brand                      merchant  \
# 0      4  None            Fresh Thyme Market
# 1      7  None                          ALDI
# 2      8  None                          ALDI
# 3      9  None                    Jewel-Osco
# 4     10  None  Angelo Caputo's Fresh Market
#
#                                                 name category  \
# 0  100% Antibiotic-Free Fresh Thyme Chicken Drums...
# 1  Bremer Buffalo Style Chicken or Mushroom & Swi...
# 2  Appetitos Buffalo Chicken or Bacon Mac & Chees...
# 3  Sesame Orange Chicken Bowl, Crispy Honey Chick...
# 4   2453 N3 PERDUE e Tano INS oue af AN PERDUE A ...
#
#                                description current_price price_text  \
# 0                                     None          1.69         LB
# 1                         22–26 oz. Frozen          5.49       None
# 2                             9 oz. Frozen          3.99       None
# 3  8 oz. - 24 oz.\nSingle Item Price $6.00           5.0        ea.
# 4                                     None                     None
#
#    percent_off                                          image_url  \
# 0          NaN  http://f.wishabi.net/page_pdf_images/11238265/...
# 1          NaN  http://f.wishabi.net/page_items/210013825/1610...
# 2          NaN  http://f.wishabi.net/page_items/210013834/1610...
# 3          NaN  http://f.wishabi.net/page_pdf_images/11232490/...
# 4          NaN  http://f.wishabi.net/page_items/212482573/1611...
#
#                                     cutout_image_url  ext_price  \
# 0  http://f.wishabi.net/page_items/211859069/1611...        NaN
# 1  http://f.wishabi.net/page_items/210013825/1610...        NaN
# 2  http://f.wishabi.net/page_items/210013834/1610...        NaN
# 3  http://f.wishabi.net/page_items/211645842/1611...        NaN
# 4  http://f.wishabi.net/page_items/212482573/1611...        NaN
#
#    ext_weight(oz)
# 0            16.0
# 1            26.0
# 2             9.0
# 3             8.0
# 4            29.0

# %%
for i in range(len(df_wgti)):
        pr_exrt = str(df_wgti['name'][i])+ ',' + str(df_wgti['description'][i]) + ','+ str(df_wgti['price_text'][i])
       
       
        if df_wgti['current_price'][i] =='':  # if price is missing in current price
            #print(i, pr_exrt)
            pxt1 =  re.findall(r'([$])(\d+(\.?)\d+)', pr_exrt)
            pxt2 =  re.findall(r'(\d+)(\s|\\n)(\d+)(\s?|\\n)(?i)(lb|lbs|oz|ea)', pr_exrt)
            pxt3 =  re.findall(r' (?i)(lb|lbs|lb.)(\s?|\\n|.)(\d+)[(.|\\n|\s?)](\d+)', pr_exrt)
            pxt4 =  re.findall(r'(?i)(Lb|Lbs|lb.)(\s?|.|\\n)(\d+)', pr_exrt)
            pxt5 =  re.findall(r'(\d+(\s?\.?)\d+)(\s?|\\n|.)(?i)(lb|lbs|\xa2|ea)', pr_exrt)
            pxt6 =  re.findall(r'(\d+)(\s?|\\n)(?i)(ea)', pr_exrt)
            
            fpxt = pxt1 or pxt2 or pxt3 or pxt4 or pxt5 or pxt6
            #print(i, fpxt, pr_exrt)    
            if fpxt !=[]:
                ext_itm = fpxt[0]  # pick the first one for multitple entries
                #print(i, fpxt[0])
                #clean data with $ in the front
                
                #print(i, fpxt, pr_exrt) 
                if ext_itm[0] == "$":
                    ext_val1 = ast.literal_eval(ext_itm[1]) # numerical value int or float
                    #print(i, ext_val1, pr_exrt)
                    if type(ext_val1) == float:
                        #print(i, ext_val1, pr_exrt)
                        df_wgti['ext_price'][i]= ext_val1
                    elif type(ext_val1) != float:
                       # print(i, ext_val1, pr_exrt)
                        df_wgti['ext_price'][i]= ext_val1/100   
                         #print(i, ext_val1, pr_exrt)
                if ext_itm[-1].lower() == 'lb':
                    #print(i, ext_itm) 
                    ext_lb0 = ast.literal_eval(ext_itm[0])
                    if len(ext_itm[0]) !=1:
                        if type(ext_lb0) == float:
                            df_wgti['ext_price'][i]=ext_lb0
                        elif len(ext_itm[0]) == 4:
                            df_wgti['ext_price'][i]=ext_lb0/1000
                            #print(i, ext_lb0)   
                        elif len(ext_itm[0]) == 3 or len(ext_itm[0])==2:
                            df_wgti['ext_price'][i]=ext_lb0/100
                           # print(i, ext_lb0) 
                    elif len(ext_itm[0])==1:  
                        n_ext = ext_itm[0] +''+'99'
                        df_wgti['ext_price'][i]=(ast.literal_eval(n_ext))/100
                        #print(i, ext_lb0) 
                        #print(ext_itm[0],ast.literal_eval(n_ext), pr_exrt)
                elif ext_itm[0].lower() =='lb' or ext_itm[0].lower() =='lb.':
                    #print(i, ext_itm[0], ext_itm[2], pr_exrt)
                    df_wgti['ext_price'][i]=(ast.literal_eval(ext_itm[2]))/100 
                elif ext_itm[-1].lower() != 'lb' and ext_itm[0] != "$":
                    if len(ext_itm[0])==2 or len(ext_itm[0]) == 3:
                        df_wgti['ext_price'][i]=(ast.literal_eval(ext_itm[0]))/100
                    else:
                        df_wgti['ext_price'][i]=np.nan     
            else:
                df_wgti['ext_price'][i] = np.nan
# Out:
# 105 ? 3   Ea  Cheloene LOI LR ChaickonaSot tv LAWT 5oz. Can In 0il OF Water Chicken of the Sea Chunk Light Tuna 48 Linnit3 Ea.,None,None

# %%
df_wgti['ext_price'].unique()

# %%
df_wgti['ext_price'].isnull().sum()

# %%
df_wgti['ext_weight(oz)'].unique()

# %%
type(df_wgti['ext_weight(oz)'])

# %%
df_wgti['ext_weight(oz)'].isnull().sum()

# %%
df_np = df_wgti[['merchant','current_price','percent_off', 'image_url','ext_price', 'ext_weight(oz)']].copy()

# %%
df_np.head()

# %%
df_np['com_price'] = np.nan

# %%
# create a new column using current and extracted price
for i in range(len(df_np)):
    old_price = df_np['current_price'][i]
    new_price = df_np['ext_price'][i]
    if old_price != '':
        df_np['com_price'][i] = old_price
    else:
        df_np['com_price'][i] = new_price

# %%
# remove missing values if any from new column
df_final = df_np.dropna(subset = ['com_price'])

# %%
df_final = df_final.reset_index(drop= True)

# %%
df_np.shape, df_final.shape

# %%
df_final.head()

# %%
df_final['final_price($/oz)'] = np.nan

# %%
for i in range(len(df_final)):
    pr_indoll = df_final['com_price'][i]
    unit_inoz = df_final['ext_weight(oz)'][i]
    df_final['final_price($/oz)'][i] = round((pr_indoll/unit_inoz),3)

# %%
 df_final['final_price($/oz)'].unique()

# %%
df_final.head()

# %%
def sort_display(df_name):
    '''
    Returns five lowest price 
    items from the dataframe.
    '''
    df_sorted = df_name.sort_values(by='final_price($/oz)')
    df_sorted = df_sorted.reset_index()
    
    if len(df_sorted) < 5:
        for i in range(len(df_sorted)):
            store_name = df_sorted['merchant'][i]
            final_price = df_sorted['final_price($/oz)'][i]
            item_image = df_sorted['image_url'][i]
            #read the image
            with urllib.request.urlopen(item_image ) as url:
                ff = io.BytesIO(url.read())
                img = Image.open(ff)
                display(store_name,img)
    else:
        for i in range(len(df_sorted)):
            if i < 5:
                store_name = df_sorted['merchant'][i]
                final_price = df_sorted['final_price($/oz)'][i]
                item_image = df_sorted['image_url'][i]
                #read the image
                with urllib.request.urlopen(item_image ) as url:
                    ff = io.BytesIO(url.read())
                    img = Image.open(ff)
                    display(store_name,img)
 
    return 
sort_display(df_final)

# %%
def sorted_bestprice(df_final):
    df_sorted = df_final.sort_values(by='final_price($/oz)')
    df_sorted = df_sorted.reset_index()

    bp_list = [] #list of tuples with best price store name, best price and image url

    if len(df_sorted) <5:
        for i in range(len(df_sorted)):
            store_name = df_sorted['merchant'][i]
            final_price = df_sorted['final_price($/oz)'][i]
            item_image = df_sorted['image_url'][i]
            bp_list.append((store_name, final_price, item_image))
    else:
        for i in range(len(df_sorted)):
            if i < 5:
                store_name = df_sorted['merchant'][i]
                final_price = df_sorted['final_price($/oz)'][i]
                item_image = df_sorted['image_url'][i]
                bp_list.append((store_name, str(final_price) +'/oz', item_image))
    return bp_list

print(len(sorted_bestprice(df_final)))    
print(sorted_bestprice(df_final))
